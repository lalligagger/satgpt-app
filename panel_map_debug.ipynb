# %%
from mapper import MapManager
from odc import ui
from odc.stac import stac_load
from odc import ui
from odc.algo import colorize, to_rgba

import pystac
from pystac_client.client import Client
import json

from ipyleaflet import Map, Marker
import panel as pn
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f8cd09ca-1ab5-46af-9c87-de7e4d3f8823'>
#   <div id="d2fb5766-c86e-4e64-be65-3a92f25e720d" data-root-id="f8cd09ca-1ab5-46af-9c87-de7e4d3f8823" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### Issues/ observations so far:
#
# - Get error tracebacks e.g.: https://gist.github.com/lalligagger/f6e013827f1feb8fc35f122c35532275
# - Thought it was on STAC catalog (json file) change, but think this was just a coincidence w/ timing.
# - Running the below, I can change the date a few times with no problem. But waiting a minute or two and trying again gives the traceback.
# - Some "no such comm" errors are expected while the page reloads on layer change. This is the only way I could get leaflet layer updates to show.
# - Note: you can ignore `agent.py` and `tools.py`, they are not used in this example.

# %%
## filepath & default user request
# filepath = './tmp/items.json'

# load map manager & stac items
map_mgr = MapManager()
try:
    list(map_mgr.panel())[0].enabled_dates = map_mgr.allow_dates
except:
    print("no items found")
button = pn.widgets.Button(name='Update Items to Map', button_type='warning')

# %%
@pn.depends(button, watch=True)
def update_items(clicks):
    map_mgr.load_items()
    # list(map_mgr.panel())[0].enabled_dates = map_mgr.allow_dates

    # map_mgr.set_date(map_mgr.allow_dates[0])
    # print("reloading page")
    
    # pn.state.location.reload = True # https://github.com/holoviz/panel/issues/3148

# %%
component = pn.Column(
    button,
    map_mgr.panel
)

template = pn.template.FastListTemplate(
    title="SatGPT",
    logo="https://panel.holoviz.org/_static/logo_stacked.png",
    main=[component],
).servable()
